# %%
import tensorflow as tf 
import pandas as pd 
import numpy as np 
from sklearn.preprocessing import StandardScaler 
import tensorflow.keras as k
from sklearn.model_selection import train_test_split 
from matplotlib import pyplot as plt 
import time

# %%
df = pd.read_csv('train.csv')

# %%
df.head()
# Out:
#       MEAN_RR   MEDIAN_RR        SDRR      RMSSD       SDSD  SDRR_RMSSD  \
# 0  885.157845  853.763730  140.972741  15.554505  15.553371    9.063146
# 1  939.425371  948.357865   81.317742  12.964439  12.964195    6.272369
# 2  898.186047  907.006860   84.497236  16.305279  16.305274    5.182201
# 3  881.757864  893.460030   90.370537  15.720468  15.720068    5.748591
# 4  809.625331  811.184865   62.766242  19.213819  19.213657    3.266724
#
#           HR      pNN25     pNN50        SD1  ...         HF    HF_PCT  \
# 0  69.499952  11.133333  0.533333  11.001565  ...  15.522602  0.421047
# 1  64.363150   5.600000  0.000000   9.170129  ...   2.108525  0.070133
# 2  67.450066  13.066667  0.200000  11.533417  ...  13.769729  0.512671
# 3  68.809562  11.800000  0.133333  11.119476  ...  18.181913  0.529387
# 4  74.565728  20.200000  0.200000  13.590641  ...  48.215822  1.839473
#
#       HF_NU           TP       LF_HF     HF_LF    sampen    higuci  datasetId  \
# 0  1.514737  3686.666157   65.018055  0.015380  2.139754  1.163485          2
# 1  0.304603  3006.487251  327.296635  0.003055  2.174499  1.084711          2
# 2  1.049528  2685.879461   94.280910  0.010607  2.135350  1.176315          2
# 3  1.775294  3434.520980   55.328701  0.018074  2.178341  1.179688          2
# 4  3.279993  2621.175204   29.487873  0.033912  2.221121  1.249612          2
#
#    condition
# 0          0
# 1          1
# 2          1
# 3          0
# 4          0
#
# [5 rows x 36 columns]

# %%
label =['condition']
features =['MEAN_RR','RMSSD','pNN25','pNN50','LF','HF','LF_HF']

# %%
scaler = StandardScaler()
scaler.fit(df[features])
df[features]=scaler.transform(df[features])

# %%
X = df[features].values 
y = df[label].values

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.3,random_state = 40)

# %%
print(X_train.shape,y_train.shape,X_test.shape,y_test.shape)
# Out:
# (258502, 7) (258502, 1) (110787, 7) (110787, 1)

# %%
y_train = k.utils.to_categorical(y_train)
y_test = k.utils.to_categorical(y_test)

# %%
from tensorflow.keras import Sequential 
from tensorflow.keras.layers import Dense

# %%
model = Sequential()
model.add(Dense(50,activation ='relu',kernel_initializer ='he_normal',input_shape=(X_train.shape[1],)))
model.add(Dense(20,activation ='relu',kernel_initializer ='he_normal'))
model.add(Dense(10,activation ='relu',kernel_initializer ='he_normal'))
model.add(Dense(3, activation = 'softmax'))

# %%
model.compile(optimizer ='adam', loss='categorical_crossentropy',metrics=['accuracy'])
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.

# %%
history = model.fit(X_train,y_train, validation_data = (X_test, y_test),epochs =50,batch_size =1024, verbose =1)
# Out:
# Epoch 1/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 9s 18ms/step - accuracy: 0.6021 - loss: 0.8509 - val_accuracy: 0.6660 - val_loss: 0.7357
# Epoch 2/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.7152 - loss: 0.6648 - val_accuracy: 0.7498 - val_loss: 0.6114
# Epoch 3/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.7679 - loss: 0.5643 - val_accuracy: 0.7861 - val_loss: 0.5260
# Epoch 4/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.8042 - loss: 0.4881 - val_accuracy: 0.8263 - val_loss: 0.4584
# Epoch 5/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.8335 - loss: 0.4283 - val_accuracy: 0.8430 - val_loss: 0.4065
# Epoch 6/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.8499 - loss: 0.3834 - val_accuracy: 0.8564 - val_loss: 0.3655
# Epoch 7/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.8624 - loss: 0.3498 - val_accuracy: 0.8677 - val_loss: 0.3372
# Epoch 8/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.8722 - loss: 0.3231 - val_accuracy: 0.8771 - val_loss: 0.3110
# Epoch 9/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.8814 - loss: 0.3001 - val_accuracy: 0.8864 - val_loss: 0.2925
# Epoch 10/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.8895 - loss: 0.2809 - val_accuracy: 0.8915 - val_loss: 0.2747
# Epoch 11/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.8956 - loss: 0.2656 - val_accuracy: 0.8966 - val_loss: 0.2617
# Epoch 12/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9035 - loss: 0.2519 - val_accuracy: 0.8990 - val_loss: 0.2528
# Epoch 13/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9078 - loss: 0.2410 - val_accuracy: 0.9093 - val_loss: 0.2365
# Epoch 14/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9121 - loss: 0.2310 - val_accuracy: 0.9143 - val_loss: 0.2292
# Epoch 15/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.9162 - loss: 0.2223 - val_accuracy: 0.9161 - val_loss: 0.2225
# Epoch 16/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9186 - loss: 0.2152 - val_accuracy: 0.9191 - val_loss: 0.2124
# Epoch 17/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9208 - loss: 0.2090 - val_accuracy: 0.9196 - val_loss: 0.2101
# Epoch 18/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9235 - loss: 0.2026 - val_accuracy: 0.9233 - val_loss: 0.2020
# Epoch 19/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9258 - loss: 0.1979 - val_accuracy: 0.9256 - val_loss: 0.1980
# Epoch 20/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.9276 - loss: 0.1927 - val_accuracy: 0.9259 - val_loss: 0.1931
# Epoch 21/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.9293 - loss: 0.1882 - val_accuracy: 0.9285 - val_loss: 0.1881
# Epoch 22/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.9309 - loss: 0.1847 - val_accuracy: 0.9295 - val_loss: 0.1832
# Epoch 23/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9319 - loss: 0.1804 - val_accuracy: 0.9312 - val_loss: 0.1809
# Epoch 24/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9333 - loss: 0.1770 - val_accuracy: 0.9319 - val_loss: 0.1781
# Epoch 25/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.9344 - loss: 0.1742 - val_accuracy: 0.9344 - val_loss: 0.1756
# Epoch 26/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9353 - loss: 0.1710 - val_accuracy: 0.9355 - val_loss: 0.1703
# Epoch 27/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9363 - loss: 0.1688 - val_accuracy: 0.9374 - val_loss: 0.1671
# Epoch 28/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9377 - loss: 0.1658 - val_accuracy: 0.9374 - val_loss: 0.1661
# Epoch 29/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.9382 - loss: 0.1633 - val_accuracy: 0.9386 - val_loss: 0.1634
# Epoch 30/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9395 - loss: 0.1603 - val_accuracy: 0.9362 - val_loss: 0.1630
# Epoch 31/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9403 - loss: 0.1581 - val_accuracy: 0.9378 - val_loss: 0.1609
# Epoch 32/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9406 - loss: 0.1566 - val_accuracy: 0.9361 - val_loss: 0.1604
# Epoch 33/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9415 - loss: 0.1547 - val_accuracy: 0.9356 - val_loss: 0.1632
# Epoch 34/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9410 - loss: 0.1541 - val_accuracy: 0.9414 - val_loss: 0.1522
# Epoch 35/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9433 - loss: 0.1504 - val_accuracy: 0.9433 - val_loss: 0.1492
# Epoch 36/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9442 - loss: 0.1483 - val_accuracy: 0.9433 - val_loss: 0.1488
# Epoch 37/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.9449 - loss: 0.1464 - val_accuracy: 0.9417 - val_loss: 0.1497
# Epoch 38/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - accuracy: 0.9464 - loss: 0.1434 - val_accuracy: 0.9423 - val_loss: 0.1489
# Epoch 39/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9463 - loss: 0.1424 - val_accuracy: 0.9451 - val_loss: 0.1439
# Epoch 40/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9475 - loss: 0.1399 - val_accuracy: 0.9459 - val_loss: 0.1429
# Epoch 41/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9478 - loss: 0.1393 - val_accuracy: 0.9460 - val_loss: 0.1401
# Epoch 42/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9486 - loss: 0.1372 - val_accuracy: 0.9458 - val_loss: 0.1423
# Epoch 43/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9489 - loss: 0.1366 - val_accuracy: 0.9474 - val_loss: 0.1398
# Epoch 44/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.9496 - loss: 0.1347 - val_accuracy: 0.9460 - val_loss: 0.1414
# Epoch 45/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.9508 - loss: 0.1326 - val_accuracy: 0.9506 - val_loss: 0.1338
# Epoch 46/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9516 - loss: 0.1310 - val_accuracy: 0.9503 - val_loss: 0.1316
# Epoch 47/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9524 - loss: 0.1289 - val_accuracy: 0.9517 - val_loss: 0.1306
# Epoch 48/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9523 - loss: 0.1290 - val_accuracy: 0.9496 - val_loss: 0.1326
# Epoch 49/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9526 - loss: 0.1274 - val_accuracy: 0.9522 - val_loss: 0.1275
# Epoch 50/50
# 253/253 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9536 - loss: 0.1260 - val_accuracy: 0.9528 - val_loss: 0.1263

# %%
pd.DataFrame(history.history).plot(figsize=(10,7))
# Out:
# <Axes: >

# %%
df_test = pd.read_csv('test.csv')

# %%
df_test[features] = scaler.transform(df_test[features])
df_test[features].head()
# Out:
#     MEAN_RR     RMSSD     pNN25     pNN50        LF        HF     LF_HF
# 0 -1.001159 -0.634891 -0.598837 -0.874583 -0.575814  0.602911 -0.295775
# 1 -0.024971  1.048686  1.361573 -0.672601  1.080403 -0.280746 -0.157544
# 2  0.897836  1.544671  1.743894  0.943254  1.965161 -0.511482  0.037412
# 3 -0.175046 -0.777935 -0.623241 -0.335965 -0.767443 -0.477196 -0.241658
# 4 -0.721825 -0.393071 -0.476820 -0.201310 -0.735541 -0.089133 -0.280126

# %%
y=k.utils.to_categorical(y)

# %%
loss,acc = model.evaluate(X,y,verbose=1)
# Out:
# 11541/11541 ━━━━━━━━━━━━━━━━━━━━ 54s 5ms/step - accuracy: 0.9539 - loss: 0.1238

# %%
data = pd.read_csv('test.csv')

# %%
t = scaler.transform(data[features].iloc[5545].values.reshape(1,-1))
print(t)
# Out:
# [[-0.7699341   0.25391942  0.11699709  0.60661783  0.54497884  0.50787441
#   -0.26537627]]
# C:\Users\Admin\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\validation.py:2827: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
y_pred = model.predict(t)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 271ms/step

# %%
print(np.argmax(y_pred[0]))
print(data[label].iloc[5545])
# Out:
# 0
# condition    0
# Name: 5545, dtype: int64

# %%
import joblib 
joblib.dump(scaler,'scaler.joblib',compress = 9)
model.save('tfmodel.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
df = pd.read_csv('train.csv')
